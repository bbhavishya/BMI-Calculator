# %% [markdown]
# <a href="https://colab.research.google.com/github/bbhavishya/BMI-Calculator/blob/branch-1/Count_of_resolver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/Service tickets information_v1.xlsx')

# %%
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#         SLA   Ticket ID        Created Date           Created By  \
# 0  09:10:00  300-533083 2022-01-02 18:23:00   Pungwilai, Ruethai
# 1  20:27:00  300-533095 2022-01-03 05:40:00       Daniels, Renee
# 2  01:19:00  300-533120 2022-01-03 09:09:00  SUDHAKAR, RAJENDRAN
# 3  07:11:00  300-533136 2022-01-03 10:00:00  SUDHAKAR, RAJENDRAN
# 4  04:27:00  300-533159 2022-01-03 10:52:00    Musikul, Waraporn
#
#                                          Description Priority    Status  \
# 0  S1_HJ_TUQ : unable to find 2 order number in w...     High  Resolved
# 1  S1 HJ ASF - Orders Shipped but not triggered i...     High    Closed
# 2                      HJ: REQUEST EDI FILES FOR MLU     High    Closed
# 3                                HJ: AUTO REPORT MDU     High    Closed
# 4  S1_HJ_Please help to check order 88134766 we c...     High    Closed
#
#   Assign To Individual     Last Resolved By  Last Resolved Date  ...  \
# ...

# %%
count = df_copy['Resolver'].value_counts()

# %%
count
# Out:
# Khalida       326
# Chitra        285
# Nagarjuna     264
# Raviteja      212
# Vimal         207
# Alya          205
# Raja          140
# Aina          124
# Sukundhen     104
# Usha           81
# Phaneendra     32
# Nirmal          7
# khalida         4
# Karthik         1
# RAviteja        1
# ALya            1
# RAJA            1
# NAgarjuna       1
# CHitra          1
# usha            1
# chitra          1
# Name: Resolver, dtype: int64

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   SLA                                1999 non-null   object
#  1   Ticket ID                          1999 non-null   object
#  2   Created Date                       1999 non-null   datetime64[ns]
#  3   Created By                         1999 non-null   object
#  4   Description                        1999 non-null   object
#  5   Priority                           1999 non-null   object
#  6   Status                             1999 non-null   object
#  7   Assign To Individual               1999 non-null   object
#  8   Last Resolved By                   1999 non-null   object
#  9   Last Resolved Date                 1999 non-null   datetime64[ns]
#  10  SLA Status                         1999 non-null   object
# ...

# %%
ravi = df_copy[df_copy.Resolver == 'Raviteja']

# %%
ravi.shape
# Out:
# (212, 28)

# %%
ravi.head()
# Out:
#                     SLA   Ticket ID        Created Date  \
# 5   1900-01-01 22:45:00  300-533201 2022-01-03 13:46:00
# 23  1900-01-01 00:08:00  300-533351 2022-01-04 12:42:00
# 49  1900-01-01 01:49:00  300-533515 2022-01-05 12:49:00
# 52             22:10:00  300-533552 2022-01-05 16:31:00
# 54             03:13:00  300-533576 2022-01-05 19:30:00
#
#                Created By                                        Description  \
# 5           Dooa, Shevons           S3 Hj - <Clarins MY> RE: MCL DailyReport
# 23  Chomnomchat, Buathong  S1_WMS1_Order isn't available in HJ order numb...
# 49         Daniels, Renee                    S1 HJ ASF - Multiple Guns Reset
# 52     shakirin, syaqinah                    S1 HJ inbound order SVB-OTH5367
# 54  Production, WLA Admin                   SR HJ 7:30PM Healtcheck 1/5/2022
#
#    Priority  Status Assign To Individual Last Resolved By  Last Resolved Date  \
# 5      High  Closed         KS, RAVITEJA     KS, RAVITEJA 2022-01-05 12:31:00
# ...

# %%
ravi.to_csv('modified data.csv',index = False)

# %%
count_of_resolver = df_copy[df_copy['Resolver'] == 'Raviteja'].shape[0]

# %%
print('The number of tickets resolved by Raviteja are : ',count_of_resolver)
# Out:
# The number of tickets resolved by Raviteja are :  212
